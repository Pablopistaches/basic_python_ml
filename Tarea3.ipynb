# %% [markdown]
# # Tarea 3: Pandas 🐼🐼🐼🐼🐼🐼
#
# Instrucciones: TODOS los ejercicios son obligatorios.
#
# 1) Antes que nada, importa la trinidad de la ciencia de datos tal como lo hicimos en el Notebook 3, a saber: pandas como pd, numpy como np y matplotlib.pyplot como plt.

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# -----------------------------

# %% [markdown]
# 2) Crea un diccionario que contenga el nombre de los últimos tres libros qué leíste así como el número de páginas aproximado de cada uno. Ya que lo tengas, usa la función DataFrame de Pandas para convertir tu diccionario en un DataFrame y por último usa el método set_index para fijar como índice el nombre del libro (no olvides fijar el parámetro inplace = True para guardar los cambios).

# %%
libro = {'libro':['Sapiens','The lady tasting tea','En busca del señor Jenkins'],'páginas':[464,340,604]}

# %%
libros = pd.DataFrame(libro) ; libros
# Out:
#                         libro  páginas
# 0                     Sapiens      464
# 1        The lady tasting tea      340
# 2  En busca del señor Jenkins      604

# %%
libros.set_index('libro', inplace=True)
libros
# Out:
#                             páginas
# libro
# Sapiens                         464
# The lady tasting tea            340
# En busca del señor Jenkins      604

# %% [markdown]
# ----

# %% [markdown]
# 3) El archivo NBA_player_of_the_week.csv contiene la información de los MVP (Jugadores Más Valiosos) de la semana desde 1985 hasta 2019. Usa la función read_csv de pandas para leer el archivo y luego la función info() para obtener más información de los datos. ¿Hay alguna variable con valores nulos?

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv')
mvp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1187 entries, 0 to 1186
# Data columns (total 14 columns):
# Active season        1187 non-null int64
# Player               1187 non-null object
# Team                 1187 non-null object
# Conference           803 non-null object
# Date                 1187 non-null object
# Position             1187 non-null object
# Height               1187 non-null object
# Weight               1187 non-null int64
# Age                  1187 non-null int64
# Draft Year           1187 non-null int64
# Seasons in league    1187 non-null int64
# Season               1187 non-null object
# Season short         1187 non-null int64
# Real_value           1187 non-null float64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 130.0+ KB

# %%
# no hay ninguna variable con valores nulos

# %% [markdown]
# 4) Usa el método head para mostrar los primeros SEIS registros del *dataset* luego escoge SÓLO dos columnas y despliéga sus primeros seis registros en la pantalla de tu computadora.

# %%
mvp.head(6)
# Out:
#    Active season                  Player                  Team Conference  \
# 0              0  Micheal Ray Richardson       New Jersey Nets        NaN
# 1              0             Derek Smith  Los Angeles Clippers        NaN
# 2              0             Calvin Natt        Denver Nuggets        NaN
# 3              0     Kareem Abdul-Jabbar    Los Angeles Lakers        NaN
# 4              0              Larry Bird        Boston Celtics        NaN
# 5              0        Darrell Griffith             Utah Jazz        NaN
#
#            Date Position Height  Weight  Age  Draft Year  Seasons in league  \
# 0  Apr 14, 1985       PG    6-5     189   29        1978                  6
# 1   Apr 7, 1985       SG    6-6     205   23        1982                  2
# 2   Apr 1, 1985        F    6-6     220   28        1979                  5
# 3  Mar 24, 1985        C    7-2     225   37        1969                 15
# 4  Mar 17, 1985       SF    6-9     220   28        1978                  5
# 5  Mar 10, 1985       SG    6-4     190   26        1980                  4
#
#       Season  Season short  Real_value
# 0  1984-1985          1985         1.0
# 1  1984-1985          1985         1.0
# 2  1984-1985          1985         1.0
# 3  1984-1985          1985         1.0
# 4  1984-1985          1985         1.0
# 5  1984-1985          1985         1.0

# %%
mvp[['Player', 'Team']].head(6)
# Out:
#                    Player                  Team
# 0  Micheal Ray Richardson       New Jersey Nets
# 1             Derek Smith  Los Angeles Clippers
# 2             Calvin Natt        Denver Nuggets
# 3     Kareem Abdul-Jabbar    Los Angeles Lakers
# 4              Larry Bird        Boston Celtics
# 5        Darrell Griffith             Utah Jazz

# %% [markdown]
# -----
# 5) Utiliza el método set_index() para indexar la columna "Team" y muestra los datos por indice (recuerda que el metodo para imprimir por
# índice es set_index() ).
#
# Una vez que tengas indexada la columna Team, muestra la información correspondiente al índice "Los Angeles Lakers" y dime cual es el valor promedio la columna "Real_value"

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv')
mvp.set_index('Team', inplace=True)
mvp
# Out:
#                        Active season                  Player Conference  \
# Team
# New Jersey Nets                    0  Micheal Ray Richardson        NaN
# Los Angeles Clippers               0             Derek Smith        NaN
# Denver Nuggets                     0             Calvin Natt        NaN
# Los Angeles Lakers                 0     Kareem Abdul-Jabbar        NaN
# Boston Celtics                     0              Larry Bird        NaN
# ...                              ...                     ...        ...
# Oklahoma City Thunder              1       Russell Westbrook       West
# Milwaukee Bucks                    1   Giannis Antetokounmpo       East
# Golden State Warriors              1           Stephen Curry       West
# Charlotte Hornets                  1            Kemba Walker       East
# Denver Nuggets                     1            Nikola Jokic       West
#
#                                Date Position Height  Weight  Age  Draft Year  \
# Team
# New Jersey Nets        Apr 14, 1985       PG    6-5     189   29        1978
# Los Angeles Clippers    Apr 7, 1985       SG    6-6     205   23        1982
# Denver Nuggets          Apr 1, 1985        F    6-6     220   28        1979
# Los Angeles Lakers     Mar 24, 1985        C    7-2     225   37        1969
# Boston Celtics         Mar 17, 1985       SF    6-9     220   28        1978
# ...                             ...      ...    ...     ...  ...         ...
# Oklahoma City Thunder   Nov 5, 2018        G    6-3     200   30        2008
# Milwaukee Bucks        Oct 29, 2018        F   6-11     242   24        2013
# Golden State Warriors  Oct 29, 2018        G    6-3     190   30        2009
# Charlotte Hornets      Oct 22, 2018        G    6-1     184   28        2011
# Denver Nuggets         Oct 22, 2018        C    7-0     250   24        2014
#
#                        Seasons in league     Season  Season short  Real_value
# Team
# New Jersey Nets                        6  1984-1985          1985         1.0
# Los Angeles Clippers                   2  1984-1985          1985         1.0
# Denver Nuggets                         5  1984-1985          1985         1.0
# Los Angeles Lakers                    15  1984-1985          1985         1.0
# Boston Celtics                         5  1984-1985          1985         1.0
# ...                                  ...        ...           ...         ...
# Oklahoma City Thunder                 10  2018-2019          2019         0.5
# Milwaukee Bucks                        5  2018-2019          2019         0.5
# Golden State Warriors                  9  2018-2019          2019         0.5
# Charlotte Hornets                      7  2018-2019          2019         0.5
# Denver Nuggets                         3  2018-2019          2019         0.5
#
# [1187 rows x 13 columns]

# %%
mvp.loc['Los Angeles Lakers']
# Out:
#                     Active season               Player Conference  \
# Team
# Los Angeles Lakers              0  Kareem Abdul-Jabbar        NaN
# Los Angeles Lakers              0        Magic Johnson        NaN
# Los Angeles Lakers              0        Magic Johnson        NaN
# Los Angeles Lakers              0        Magic Johnson        NaN
# Los Angeles Lakers              0        Magic Johnson        NaN
# ...                           ...                  ...        ...
# Los Angeles Lakers              0          Kobe Bryant       West
# Los Angeles Lakers              0          Kobe Bryant       West
# Los Angeles Lakers              0          Kobe Bryant       West
# Los Angeles Lakers              0          Kobe Bryant       West
# Los Angeles Lakers              0          Kobe Bryant       West
#
#                             Date Position Height  Weight  Age  Draft Year  \
# Team
# Los Angeles Lakers  Mar 24, 1985        C    7-2     225   37        1969
# Los Angeles Lakers  Feb 17, 1985       PG    6-9     255   25        1979
# Los Angeles Lakers   Mar 9, 1986       PG    6-9     255   26        1979
# Los Angeles Lakers   Apr 5, 1987       PG    6-9     255   27        1979
# Los Angeles Lakers  Mar 22, 1987       PG    6-9     255   27        1979
# ...                          ...      ...    ...     ...  ...         ...
# Los Angeles Lakers  Jan 16, 2012       SG    6-6     212   33        1996
# Los Angeles Lakers   Jan 9, 2012       SG    6-6     212   33        1996
# Los Angeles Lakers  Apr 15, 2013       SG    6-6     212   34        1996
# Los Angeles Lakers  Mar 11, 2013       SG    6-6     212   34        1996
# Los Angeles Lakers  Feb 25, 2013       SG    6-6     212   34        1996
#
#                     Seasons in league     Season  Season short  Real_value
# Team
# Los Angeles Lakers                 15  1984-1985          1985         1.0
# Los Angeles Lakers                  5  1984-1985          1985         1.0
# Los Angeles Lakers                  6  1985-1986          1986         1.0
# Los Angeles Lakers                  7  1986-1987          1987         1.0
# Los Angeles Lakers                  7  1986-1987          1987         1.0
# ...                               ...        ...           ...         ...
# Los Angeles Lakers                 15  2011-2012          2012         0.5
# Los Angeles Lakers                 15  2011-2012          2012         0.5
# Los Angeles Lakers                 16  2012-2013          2013         0.5
# Los Angeles Lakers                 16  2012-2013          2013         0.5
# Los Angeles Lakers                 16  2012-2013          2013         0.5
#
# [71 rows x 13 columns]

# %%
mvp[['Real_value']].mean()
# Out:
# Real_value    0.661752
# dtype: float64

# %% [markdown]
# -----
# 6) Busca al jugador "Larry Bird" en "Player" por medio de condicionales y después dime cuantas veces aparece ese nombre en el dataframe con el método len()

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv')
mvp[mvp.Player == 'Larry Bird']
# Out:
#     Active season      Player            Team Conference          Date  \
# 4               0  Larry Bird  Boston Celtics        NaN  Mar 17, 1985
# 27              0  Larry Bird  Boston Celtics        NaN  Mar 16, 1986
# 31              0  Larry Bird  Boston Celtics        NaN  Feb 16, 1986
# 34              0  Larry Bird  Boston Celtics        NaN  Jan 19, 1986
# 41              0  Larry Bird  Boston Celtics        NaN   Dec 1, 1985
# 60              0  Larry Bird  Boston Celtics        NaN   Jan 4, 1987
# 91              0  Larry Bird  Boston Celtics        NaN  Nov 15, 1987
#
#    Position Height  Weight  Age  Draft Year  Seasons in league     Season  \
# 4        SF    6-9     220   28        1978                  5  1984-1985
# 27       SF    6-9     220   29        1978                  6  1985-1986
# 31       SF    6-9     220   29        1978                  6  1985-1986
# 34       SF    6-9     220   29        1978                  6  1985-1986
# 41       SF    6-9     220   29        1978                  6  1985-1986
# 60       SF    6-9     220   30        1978                  7  1986-1987
# 91       SF    6-9     220   31        1978                  8  1987-1988
#
#     Season short  Real_value
# 4           1985         1.0
# 27          1986         1.0
# 31          1986         1.0
# 34          1986         1.0
# 41          1986         1.0
# 60          1987         1.0
# 91          1988         1.0

# %%
len(mvp[mvp.Player == 'Larry Bird'])
# Out:
# 7

# %% [markdown]
# 7) Busca al jugador "Michael Jordan" dentro de la columna "Player" por el método que más te acomode. Cuenta el número de equipos en los que jugó. Hint: puedes utilizar el método nunique o Googlea el método value_counts. Haz un gráfico con tu respuesta.

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv')
mvp.set_index('Player', inplace=True)
mvp
mvp.loc['Michael Jordan']
# Out:
#                 Active season                Team Conference          Date  \
# Player
# Michael Jordan              0       Chicago Bulls        NaN  Jan 20, 1985
# Michael Jordan              0       Chicago Bulls        NaN  Apr 12, 1987
# Michael Jordan              0       Chicago Bulls        NaN   Mar 1, 1987
# Michael Jordan              0       Chicago Bulls        NaN   Nov 9, 1986
# Michael Jordan              0       Chicago Bulls        NaN   Apr 3, 1988
# Michael Jordan              0       Chicago Bulls        NaN  Mar 27, 1988
# Michael Jordan              0       Chicago Bulls        NaN  Jan 24, 1988
# Michael Jordan              0       Chicago Bulls        NaN   Apr 2, 1989
# Michael Jordan              0       Chicago Bulls        NaN  Mar 26, 1989
# Michael Jordan              0       Chicago Bulls        NaN  Jan 15, 1989
# Michael Jordan              0       Chicago Bulls        NaN  Nov 20, 1988
# Michael Jordan              0       Chicago Bulls        NaN   Apr 1, 1990
# Michael Jordan              0       Chicago Bulls        NaN  Dec 10, 1989
# Michael Jordan              0       Chicago Bulls        NaN  Dec 23, 1990
# Michael Jordan              0       Chicago Bulls        NaN   Dec 2, 1990
# Michael Jordan              0       Chicago Bulls        NaN  Jan 12, 1992
# Michael Jordan              0       Chicago Bulls        NaN  Nov 22, 1992
# Michael Jordan              0       Chicago Bulls        NaN  Mar 10, 1996
# Michael Jordan              0       Chicago Bulls        NaN  Jan 21, 1996
# Michael Jordan              0       Chicago Bulls        NaN  Dec 24, 1995
# Michael Jordan              0       Chicago Bulls        NaN   Apr 5, 1998
# Michael Jordan              0       Chicago Bulls        NaN  Dec 21, 1997
# Michael Jordan              0       Chicago Bulls        NaN  Nov 23, 1997
# Michael Jordan              0  Washington Wizards       East   Mar 2, 2003
# Michael Jordan              0  Washington Wizards       East   Jan 5, 2003
#
#                Position Height  Weight  Age  Draft Year  Seasons in league  \
# Player
# Michael Jordan       SG    6-6     215   22        1984                  0
# Michael Jordan       SG    6-6     215   24        1984                  2
# Michael Jordan       SG    6-6     215   24        1984                  2
# Michael Jordan       SG    6-6     215   24        1984                  2
# Michael Jordan       SG    6-6     215   25        1984                  3
# Michael Jordan       SG    6-6     215   25        1984                  3
# Michael Jordan       SG    6-6     215   25        1984                  3
# Michael Jordan       SG    6-6     215   26        1984                  4
# Michael Jordan       SG    6-6     215   26        1984                  4
# Michael Jordan       SG    6-6     215   26        1984                  4
# Michael Jordan       SG    6-6     215   26        1984                  4
# Michael Jordan       SG    6-6     215   27        1984                  5
# Michael Jordan       SG    6-6     215   27        1984                  5
# Michael Jordan       SG    6-6     215   28        1984                  6
# Michael Jordan       SG    6-6     215   28        1984                  6
# Michael Jordan       SG    6-6     215   29        1984                  7
# Michael Jordan       SG    6-6     215   30        1984                  8
# Michael Jordan       SG    6-6     215   33        1984                 10
# Michael Jordan       SG    6-6     215   33        1984                 10
# Michael Jordan       SG    6-6     215   33        1984                 10
# Michael Jordan       SG    6-6     215   35        1984                 12
# Michael Jordan       SG    6-6     215   35        1984                 12
# Michael Jordan       SG    6-6     215   35        1984                 12
# Michael Jordan       SG    6-6     215   40        1984                 14
# Michael Jordan       SG    6-6     215   40        1984                 14
#
#                    Season  Season short  Real_value
# Player
# Michael Jordan  1984-1985          1985         1.0
# Michael Jordan  1986-1987          1987         1.0
# Michael Jordan  1986-1987          1987         1.0
# Michael Jordan  1986-1987          1987         1.0
# Michael Jordan  1987-1988          1988         1.0
# Michael Jordan  1987-1988          1988         1.0
# Michael Jordan  1987-1988          1988         1.0
# Michael Jordan  1988-1989          1989         1.0
# Michael Jordan  1988-1989          1989         1.0
# Michael Jordan  1988-1989          1989         1.0
# Michael Jordan  1988-1989          1989         1.0
# Michael Jordan  1989-1990          1990         1.0
# Michael Jordan  1989-1990          1990         1.0
# Michael Jordan  1990-1991          1991         1.0
# Michael Jordan  1990-1991          1991         1.0
# Michael Jordan  1991-1992          1992         1.0
# Michael Jordan  1992-1993          1993         1.0
# Michael Jordan  1995-1996          1996         1.0
# Michael Jordan  1995-1996          1996         1.0
# Michael Jordan  1995-1996          1996         1.0
# Michael Jordan  1997-1998          1998         1.0
# Michael Jordan  1997-1998          1998         1.0
# Michael Jordan  1997-1998          1998         1.0
# Michael Jordan  2002-2003          2003         0.5
# Michael Jordan  2002-2003          2003         0.5

# %%
#mvp.Team.value_counts()
mvp.loc['Michael Jordan'].Team.value_counts()
# Out:
# Chicago Bulls         23
# Washington Wizards     2
# Name: Team, dtype: int64

# %%
mvp.loc['Michael Jordan'].Team.unique()
# Out:
# array(['Chicago Bulls', 'Washington Wizards'], dtype=object)

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv')
mvp[mvp.Player == 'Michael Jordan']
# Out:
#      Active season          Player                Team Conference  \
# 11               0  Michael Jordan       Chicago Bulls        NaN
# 47               0  Michael Jordan       Chicago Bulls        NaN
# 53               0  Michael Jordan       Chicago Bulls        NaN
# 68               0  Michael Jordan       Chicago Bulls        NaN
# 72               0  Michael Jordan       Chicago Bulls        NaN
# 73               0  Michael Jordan       Chicago Bulls        NaN
# 81               0  Michael Jordan       Chicago Bulls        NaN
# 95               0  Michael Jordan       Chicago Bulls        NaN
# 96               0  Michael Jordan       Chicago Bulls        NaN
# 105              0  Michael Jordan       Chicago Bulls        NaN
# 113              0  Michael Jordan       Chicago Bulls        NaN
# 118              0  Michael Jordan       Chicago Bulls        NaN
# 133              0  Michael Jordan       Chicago Bulls        NaN
# 154              0  Michael Jordan       Chicago Bulls        NaN
# 157              0  Michael Jordan       Chicago Bulls        NaN
# 174              0  Michael Jordan       Chicago Bulls        NaN
# 205              0  Michael Jordan       Chicago Bulls        NaN
# 259              0  Michael Jordan       Chicago Bulls        NaN
# 266              0  Michael Jordan       Chicago Bulls        NaN
# 270              0  Michael Jordan       Chicago Bulls        NaN
# 303              0  Michael Jordan       Chicago Bulls        NaN
# 317              0  Michael Jordan       Chicago Bulls        NaN
# 321              0  Michael Jordan       Chicago Bulls        NaN
# 440              0  Michael Jordan  Washington Wizards       East
# 455              0  Michael Jordan  Washington Wizards       East
#
#              Date Position Height  Weight  Age  Draft Year  Seasons in league  \
# 11   Jan 20, 1985       SG    6-6     215   22        1984                  0
# 47   Apr 12, 1987       SG    6-6     215   24        1984                  2
# 53    Mar 1, 1987       SG    6-6     215   24        1984                  2
# 68    Nov 9, 1986       SG    6-6     215   24        1984                  2
# 72    Apr 3, 1988       SG    6-6     215   25        1984                  3
# 73   Mar 27, 1988       SG    6-6     215   25        1984                  3
# 81   Jan 24, 1988       SG    6-6     215   25        1984                  3
# 95    Apr 2, 1989       SG    6-6     215   26        1984                  4
# 96   Mar 26, 1989       SG    6-6     215   26        1984                  4
# 105  Jan 15, 1989       SG    6-6     215   26        1984                  4
# 113  Nov 20, 1988       SG    6-6     215   26        1984                  4
# 118   Apr 1, 1990       SG    6-6     215   27        1984                  5
# 133  Dec 10, 1989       SG    6-6     215   27        1984                  5
# 154  Dec 23, 1990       SG    6-6     215   28        1984                  6
# 157   Dec 2, 1990       SG    6-6     215   28        1984                  6
# 174  Jan 12, 1992       SG    6-6     215   29        1984                  7
# 205  Nov 22, 1992       SG    6-6     215   30        1984                  8
# 259  Mar 10, 1996       SG    6-6     215   33        1984                 10
# 266  Jan 21, 1996       SG    6-6     215   33        1984                 10
# 270  Dec 24, 1995       SG    6-6     215   33        1984                 10
# 303   Apr 5, 1998       SG    6-6     215   35        1984                 12
# 317  Dec 21, 1997       SG    6-6     215   35        1984                 12
# 321  Nov 23, 1997       SG    6-6     215   35        1984                 12
# 440   Mar 2, 2003       SG    6-6     215   40        1984                 14
# 455   Jan 5, 2003       SG    6-6     215   40        1984                 14
#
#         Season  Season short  Real_value
# 11   1984-1985          1985         1.0
# 47   1986-1987          1987         1.0
# 53   1986-1987          1987         1.0
# 68   1986-1987          1987         1.0
# 72   1987-1988          1988         1.0
# 73   1987-1988          1988         1.0
# 81   1987-1988          1988         1.0
# 95   1988-1989          1989         1.0
# 96   1988-1989          1989         1.0
# 105  1988-1989          1989         1.0
# 113  1988-1989          1989         1.0
# 118  1989-1990          1990         1.0
# 133  1989-1990          1990         1.0
# 154  1990-1991          1991         1.0
# 157  1990-1991          1991         1.0
# 174  1991-1992          1992         1.0
# 205  1992-1993          1993         1.0
# 259  1995-1996          1996         1.0
# 266  1995-1996          1996         1.0
# 270  1995-1996          1996         1.0
# 303  1997-1998          1998         1.0
# 317  1997-1998          1998         1.0
# 321  1997-1998          1998         1.0
# 440  2002-2003          2003         0.5
# 455  2002-2003          2003         0.5

# %%
mvp[mvp.Player == 'Michael Jordan'].Team.value_counts()
# Out:
# Chicago Bulls         23
# Washington Wizards     2
# Name: Team, dtype: int64

# %%
# mvp.Team.unique()
mvp[mvp.Player == 'Michael Jordan'].Team.unique()
# Out:
# array(['Chicago Bulls', 'Washington Wizards'], dtype=object)

# %% [markdown]
# -----
# 8) Entra a la página de estilos de Matplotlib [aquí](https://matplotlib.org/gallery/style_sheets/style_sheets_reference.html). Escoge el que más te guste, copia su nombre y ejecuta la línea de abajo con ese estilo para que todas tus gráficas usen ese formato. Haz un histograma con las edades de los datos y enchula tu gráfica (título, etiquetas a eje x, a eje y, o cualquier otra cosa que consideres apropiada). ¿Cuáles son las medidas de tendencia central de la variable edad? ¿Cuál es el cuantil/percentil 75 de los datos? ¿Aproximadamente en qué rango de edad se encuentra la mayoría de los jugadores de la semana?

# %%
from matplotlib import pyplot as plt

# %%
mvp = pd.read_csv('NBA_player_of_the_week.csv'); mvp.columns
# Out:
# Index(['Active season', 'Player', 'Team', 'Conference', 'Date', 'Position',
#        'Height', 'Weight', 'Age', 'Draft Year', 'Seasons in league', 'Season',
#        'Season short', 'Real_value'],
#       dtype='object')

# %%
plt.style.use('bmh') #embellecer graficas

# %%
mvp.Age.hist()
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Histograma de la edad')
# Out:
# Text(0.5, 1.0, 'Histograma de la edad')

# %%
mvp.Age.mean
mvp.Age.median
mvp.Age.mode
# Out:
# <bound method Series.mode of 0       29
# 1       23
# 2       28
# 3       37
# 4       28
#         ..
# 1182    30
# 1183    24
# 1184    30
# 1185    28
# 1186    24
# Name: Age, Length: 1187, dtype: int64>

# %%
mvp.Age.quantile(0.75)
# Out:
# 29.0

# %%
mvp.quantile(np.arange(0,1,0.1))
# Out:
#      Active season  Weight   Age  Draft Year  Seasons in league  Season short  \
# 0.0            0.0   150.0  19.0      1969.0                0.0        1985.0
# 0.1            0.0   185.0  23.0      1984.0                2.0        1990.0
# 0.2            0.0   199.0  24.0      1987.0                3.0        1995.0
# 0.3            0.0   210.0  25.0      1994.0                4.0        2000.0
# 0.4            0.0   215.0  25.0      1996.0                5.0        2003.4
# 0.5            0.0   225.0  26.0      1998.0                6.0        2006.0
# 0.6            0.0   240.0  27.0      2002.0                6.0        2009.0
# 0.7            0.0   245.0  28.0      2003.0                7.0        2011.0
# 0.8            0.0   250.0  30.0      2007.0                9.0        2014.0
# 0.9            0.0   260.0  31.0      2010.0               10.0        2017.0
#
#      Real_value
# 0.0         0.5
# 0.1         0.5
# 0.2         0.5
# 0.3         0.5
# 0.4         0.5
# 0.5         0.5
# 0.6         0.5
# 0.7         1.0
# 0.8         1.0
# 0.9         1.0

# %%
mvp['Age'].value_counts()[:22].plot(kind='barh')

# %%
mvp.Age.value_counts()
# Out:
# 25    150
# 28    132
# 27    129
# 24    126
# 26    123
# 23    102
# 29     84
# 30     74
# 22     60
# 31     58
# 32     42
# 33     30
# 21     25
# 34     16
# 20     12
# 35      8
# 37      5
# 36      3
# 38      3
# 40      2
# 19      2
# 39      1
# Name: Age, dtype: int64
